# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/plastic_waste_prediction_dataset_2000.csv')
df.head()
# Out:
#        Region  Population  Urbanization_Rate (%)  GDP_Per_Capita  \
# 0     Gujarat     2678443                  54.35        14310.00
# 1      Kerala    15979419                  86.30         9415.61
# 2     Gujarat    46412533                  41.82         3567.66
# 3     Gujarat    40627281                  39.07         5090.03
# 4  Tamil Nadu     2999657                  68.51         1650.31
#
#    Industrialization_Index  Plastic_Consumption_Per_Capita (kg)  \
# 0                    75.88                                43.91
# 1                    73.73                                 6.34
# 2                    37.38                                39.11
# 3                    42.97                                34.64
# 4                    64.68                                16.08
#
#    Waste_Management_Efficiency (%)  Recycling_Rate (%)  Education_Index  \
# 0                            31.70               20.92             0.34
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Region                               2000 non-null   object
#  1   Population                           2000 non-null   int64
#  2   Urbanization_Rate (%)                2000 non-null   float64
#  3   GDP_Per_Capita                       2000 non-null   float64
#  4   Industrialization_Index              2000 non-null   float64
#  5   Plastic_Consumption_Per_Capita (kg)  2000 non-null   float64
#  6   Waste_Management_Efficiency (%)      2000 non-null   float64
#  7   Recycling_Rate (%)                   2000 non-null   float64
#  8   Education_Index                      2000 non-null   float64
#  9   Govt_Policy_Score                    2000 non-null   int64
#  10  Plastic_Waste_Generated (tons)       2000 non-null   float64
# ...

# %%
df.describe()
# Out:
#          Population  Urbanization_Rate (%)  GDP_Per_Capita  \
# count  2.000000e+03            2000.000000     2000.000000
# mean   2.589318e+07              62.337100     8070.615560
# std    1.399525e+07              18.684737     4033.657343
# min    1.072900e+06              30.000000     1005.740000
# 25%    1.374770e+07              45.760000     4592.415000
# 50%    2.600104e+07              62.075000     8139.015000
# 75%    3.818631e+07              78.665000    11412.795000
# max    4.999958e+07              94.930000    14995.420000
#
#        Industrialization_Index  Plastic_Consumption_Per_Capita (kg)  \
# count               2000.00000                          2000.000000
# mean                  54.90300                            36.732535
# std                   25.91152                            18.944904
# min                   10.02000                             5.000000
# 25%                   32.70000                            19.867500
# ...

# %%
sns.histplot(df["Plastic_Waste_Generated (tons)"])
plt.plot()
# Out:
# []

# %%
df.isnull().sum()
# Out:
# Region                                 0
# Population                             0
# Urbanization_Rate (%)                  0
# GDP_Per_Capita                         0
# Industrialization_Index                0
# Plastic_Consumption_Per_Capita (kg)    0
# Waste_Management_Efficiency (%)        0
# Recycling_Rate (%)                     0
# Education_Index                        0
# Govt_Policy_Score                      0
# Plastic_Waste_Generated (tons)         0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df["Region"] = label_encoder.fit_transform(df["Region"])

# %%
df.head()
# Out:
#    Region  Population  Urbanization_Rate (%)  GDP_Per_Capita  \
# 0       1     2678443                  54.35        14310.00
# 1       3    15979419                  86.30         9415.61
# 2       1    46412533                  41.82         3567.66
# 3       1    40627281                  39.07         5090.03
# 4       7     2999657                  68.51         1650.31
#
#    Industrialization_Index  Plastic_Consumption_Per_Capita (kg)  \
# 0                    75.88                                43.91
# 1                    73.73                                 6.34
# 2                    37.38                                39.11
# 3                    42.97                                34.64
# 4                    64.68                                16.08
#
#    Waste_Management_Efficiency (%)  Recycling_Rate (%)  Education_Index  \
# 0                            31.70               20.92             0.34
# ...

# %%
df.drop(columns=["Education_Index"],inplace=True)

# %%
df.head()
# Out:
#    Region  Population  Urbanization_Rate (%)  GDP_Per_Capita  \
# 0       1     2678443                  54.35        14310.00
# 1       3    15979419                  86.30         9415.61
# 2       1    46412533                  41.82         3567.66
# 3       1    40627281                  39.07         5090.03
# 4       7     2999657                  68.51         1650.31
#
#    Industrialization_Index  Plastic_Consumption_Per_Capita (kg)  \
# 0                    75.88                                43.91
# 1                    73.73                                 6.34
# 2                    37.38                                39.11
# 3                    42.97                                34.64
# 4                    64.68                                16.08
#
#    Waste_Management_Efficiency (%)  Recycling_Rate (%)  Govt_Policy_Score  \
# 0                            31.70               20.92                  5
# ...

# %%
df.drop(columns=["Govt_Policy_Score"],inplace=True)

# %%
df.head()
# Out:
#    Region  Population  Urbanization_Rate (%)  GDP_Per_Capita  \
# 0       1     2678443                  54.35        14310.00
# 1       3    15979419                  86.30         9415.61
# 2       1    46412533                  41.82         3567.66
# 3       1    40627281                  39.07         5090.03
# 4       7     2999657                  68.51         1650.31
#
#    Industrialization_Index  Plastic_Consumption_Per_Capita (kg)  \
# 0                    75.88                                43.91
# 1                    73.73                                 6.34
# 2                    37.38                                39.11
# 3                    42.97                                34.64
# 4                    64.68                                16.08
#
#    Waste_Management_Efficiency (%)  Recycling_Rate (%)  \
# 0                            31.70               20.92
# 1                            92.74               68.27
# ...

# %%
x = df.drop(columns=["Plastic_Waste_Generated (tons)"])
y = df["Plastic_Waste_Generated (tons)"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
ypred = model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
mae = mean_absolute_error(y_test,ypred)
mse = mean_squared_error(y_test,ypred)
r2 = r2_score(y_test,ypred)
print("mean absolute error:", mae)
print("mean squared error:", mse)
print("r2 score:", r2)
# Out:
# mean absolute error: 91485.07965271383
# mean squared error: 17234251670.82031
# r2 score: 0.7216304318881857

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
model.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
ypred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,ypred)
# Out:
# 0.8677811946087559
